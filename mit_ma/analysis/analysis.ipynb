# %%
import pandas as pd

# %%
df = pd.read_csv("./data/slurm-log.csv")

# %%
df["partition"].unique()
# Out:
# array(['normal', 'test', 'gaia', 'xeon-p8', 'db'], dtype=object)

# %%
df.iloc[65665]
# Out:
# id_job                                                   31993221736273
# id_array_job                                             16618712154521
# id_array_task                                                4294967294
# id_user                                                  76175544093974
# kill_requid                                              61026541062099
# nodes_alloc                                                           5
# nodelist              ['r4229531-n851693', 'r1457839-n851693', 'r627...
# cpus_req                                                             75
# derived_ec                                                            0
# exit_code                                                             0
# gres_used                                                           NaN
# array_max_tasks                                                       0
# array_task_pending                                                    0
# ...

# %%
df["cpus_req"].describe()
# Out:
# count    395914.000000
# mean          9.233937
# std          63.951753
# min           1.000000
# 25%           1.000000
# 50%           4.000000
# 75%           8.000000
# max        8480.000000
# Name: cpus_req, dtype: float64

# %%
labelled = pd.read_csv("./data/labelled_jobids.csv")

# %%
ml_jobs = df[df['id_job'].isin(labelled['id_job'])]

# %%
ml_jobs
# Out:
#                 id_job    id_array_job  id_array_task         id_user  \
# 187791   8835225905106  16618712154521     4294967294   5042570016904
# 187795  34616588030023  16618712154521     4294967294   5042570016904
# 188324  35241407908821  16618712154521     4294967294   5042570016904
# 188325  89347374934753  16618712154521     4294967294   5042570016904
# 188326  38572114883328  16618712154521     4294967294   5042570016904
# ...                ...             ...            ...             ...
# 391625  60281059510701  16618712154521     4294967294   5042570016904
# 391626  66048555673701  16618712154521     4294967294   5042570016904
# 394068  89760947853207  16618712154521     4294967294  28063009141185
# 394074  79031822153895  16618712154521     4294967294  28063009141185
# 394077  52106808440658  16618712154521     4294967294  28063009141185
#
#            kill_requid  nodes_alloc  \
# 187791  61026541062099            1
# 187795  61026541062099            1
# ...
